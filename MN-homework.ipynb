# %%
import pandas as pd

# %%
df = pd.read_excel("SA_CSHomePrice_History_0228.xls")
df
# Out:
#                          AZ-Phoenix CA-Los Angeles CA-San Diego  \
# 0                   YEAR    PHXR-SA        LXXR-SA      SDXR-SA
# 1    1987-01-01 00:00:00        NaN          59.43        54.79
# 2    1987-02-01 00:00:00        NaN          59.89        55.22
# 3    1987-03-01 00:00:00        NaN           60.4        55.49
# 4    1987-04-01 00:00:00        NaN          61.32        56.05
# ..                   ...        ...            ...          ...
# 428  2022-08-01 00:00:00     333.22         405.12       401.27
# 429  2022-09-01 00:00:00     326.37         398.65       394.62
# 430  2022-10-01 00:00:00     322.57         396.96       393.28
# 431  2022-11-01 00:00:00     318.11         394.31       390.76
# 432  2022-12-01 00:00:00      313.9         392.56          388
#
#     CA-San Francisco CO-Denver DC-Washington FL-Miami FL-Tampa GA-Atlanta  \
# 0            SFXR-SA   DNXR-SA       WDXR-SA  MIXR-SA  TPXR-SA    ATXR-SA
# ...
